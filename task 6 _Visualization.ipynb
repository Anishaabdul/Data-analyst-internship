# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\anish'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.matplotlib',
#  '.ms-ad',
#  '.streamlit',
#  '.venv',
#  '.vscode',
#  'ai writer.ipynb',
#  'ai-writer',
#  'app.py',
#  'AppData',
#  'Application Data',
#  'breast-cancer.csv',
#  'cleaned_data.csv',
#  'clustered_data.csv',
#  'Contacts',
#  'Cookies',
#  'creditcard.csv',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'fraud detection.ipynb',
#  'fraud-detection',
#  'Insights.txt',
#  'insights.txt.txt',
#  'Iris.csv',
#  'library-management-system',
#  'Links',
#  'Local Settings',
#  'Mall_Customers.csv',
#  'Microsoft',
#  'model.pkl',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New folder',
#  'New folder (2)',
#  'New folder (3)',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{6e73a8d4-84fb-11ef-b695-4438e8659577}.TM.blf',
#  'NTUSER.DAT{6e73a8d4-84fb-11ef-b695-4438e8659577}.TMContainer00000000000000000001.regtrans-ms',
# ...
